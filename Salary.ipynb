# %% [markdown]
# <a href="https://colab.research.google.com/github/Lavan1999/100-dataset-8--Salary/blob/main/Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# # **Reading Dataset**

# %%
df = pd.read_csv("/content/Salary_Data.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %% [markdown]
# # **Supervised Learning, Regression**

# %%
'''
1---Supervised Data - Regression

Independent  = YearsExperience
Dependent = Salary

continuous column = YearsExperience, Salary
Category column =  None

2---Correlation Test for Numerical columns

2--- Hypothesis testing: continuous Vs continuous

3---Hypothesis testing for category VS continous
'''

# %% [markdown]
# # **correlation test**

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
'''
Correlation Test for Numerical Columns
By the result of correlation Test,


Related columns - YearsExperience	- Salary'''

# %% [markdown]
# # **One sample test**

# %%
#Hypothesis one sample test- YearExperience

for i in range(7):
  sample = df.YearsExperience.sample(frac = 0.05)
  t_test, p_value = stats.ttest_1samp(sample, df.YearsExperience.mean())
  if p_value > 0.05:
    print("H0 Hypothesis null value is accepted, there is no significance difference")
  else:
    print("H0 Hypothesis null value is rejected, there is a significance difference")
# Out:
# H0 Hypothesis null value is accepted, there is no significance difference
# H0 Hypothesis null value is accepted, there is no significance difference
# H0 Hypothesis null value is accepted, there is no significance difference
# H0 Hypothesis null value is accepted, there is no significance difference
# H0 Hypothesis null value is accepted, there is no significance difference
# H0 Hypothesis null value is accepted, there is no significance difference
# H0 Hypothesis null value is accepted, there is no significance difference

# %%
#Hypothesis one sample test- Salary

for i in range(7):
  sample = df.Salary.sample(frac = 0.04)
  t_test, p_value = stats.ttest_1samp(sample, df.Salary.mean())
  if p_value > 0.05:
    print("H0 Hypothesis null value is accepted, there is no significance difference")
  else:
    print("H0 Hypothesis null value is rejected, there is a significance difference")
# Out:
# H0 Hypothesis null value is rejected, there is a significance difference
# H0 Hypothesis null value is rejected, there is a significance difference
# H0 Hypothesis null value is rejected, there is a significance difference
# H0 Hypothesis null value is rejected, there is a significance difference
# H0 Hypothesis null value is rejected, there is a significance difference
# H0 Hypothesis null value is rejected, there is a significance difference
# H0 Hypothesis null value is rejected, there is a significance difference
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:1103: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:1103: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero

# %% [markdown]
# # **Central Limit Theorem**

# %%
#Central limit theorem: YearsExperiance

population = df.YearsExperience.values
res1 = population.mean()

samplesize = 5

sample_mean= []
for i in range(8):
  sample = np.random.choice(population, samplesize)
  sample_mean.append(sample)

res2 = np.mean(sample_mean)
print(res1,res2)
# Out:
# 5.3133333333333335 5.2675

# %%
#Central limit theorem: Salary

population = df.Salary.values
res1 = population.mean()

samplesize = 5

sample_mean= []
for i in range(8):
  sample = np.random.choice(population, samplesize)
  sample_mean.append(sample)

res2 = np.mean(sample_mean)
print(res1,res2)
# Out:
# 76003.0 76890.075

# %% [markdown]
# # **Two sample Test**

# %%
#Hypothesis two sample ttest - Price Vs Rating
for i in range(10):
  sample1 = df.YearsExperience.sample(frac=0.04)
  sample2 = df.Salary.sample(frac=0.05)
  t_value, p_value = stats.ttest_ind(sample1, sample2)

  if p_value > 0.05:
    print("H0 Null hypothesis is accepted and there is no significance difference between two columns")
  else:
    print("H0 Null hypothesis is rejected and there is a significance difference between two columns")

#H0 is accepted
# Out:
# H0 Null hypothesis is rejected and there is a significance difference between two columns
# H0 Null hypothesis is accepted and there is no significance difference between two columns
# H0 Null hypothesis is accepted and there is no significance difference between two columns
# H0 Null hypothesis is accepted and there is no significance difference between two columns
# H0 Null hypothesis is accepted and there is no significance difference between two columns
# H0 Null hypothesis is accepted and there is no significance difference between two columns
# H0 Null hypothesis is accepted and there is no significance difference between two columns
# H0 Null hypothesis is accepted and there is no significance difference between two columns
# H0 Null hypothesis is accepted and there is no significance difference between two columns
# H0 Null hypothesis is accepted and there is no significance difference between two columns

# %%
x = df["YearsExperience"]
y = df["Salary"]

# %%
import plotly.express as px

# %%
fig = px.scatter(df, x , y , trendline = "ols")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Machine Learning**

# %%
import statsmodels.api as sm

# %%
x1 = df["YearsExperience"]
y = df["Salary"]

x = sm.add_constant(x1)
x
# Out:
#     const  YearsExperience
# 0     1.0              1.1
# 1     1.0              1.3
# 2     1.0              1.5
# 3     1.0              2.0
# 4     1.0              2.2
# 5     1.0              2.9
# 6     1.0              3.0
# 7     1.0              3.2
# 8     1.0              3.2
# 9     1.0              3.7
# 10    1.0              3.9
# 11    1.0              4.0
# 12    1.0              4.0
# 13    1.0              4.1
# 14    1.0              4.5
# 15    1.0              4.9
# 16    1.0              5.1
# 17    1.0              5.3
# 18    1.0              5.9
# 19    1.0              6.0
# 20    1.0              6.8
# 21    1.0              7.1
# 22    1.0              7.9
# 23    1.0              8.2
# 24    1.0              8.7
# 25    1.0              9.0
# 26    1.0              9.5
# 27    1.0              9.6
# 28    1.0             10.3
# 29    1.0             10.5

# %%
model = sm.OLS(y,x)
result = model.fit()

yhat = result.params[0]+result.params[1]* x1
yhat
# Out:
# 0      36187.158752
# 1      38077.151217
# 2      39967.143681
# 3      44692.124842
# 4      46582.117306
# 5      53197.090931
# 6      54142.087163
# 7      56032.079627
# 8      56032.079627
# 9      60757.060788
# 10     62647.053252
# 11     63592.049484
# 12     63592.049484
# 13     64537.045717
# 14     68317.030645
# 15     72097.015574
# 16     73987.008038
# 17     75877.000502
# 18     81546.977895
# 19     82491.974127
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# Name: YearsExperience, dtype: float64

# %%
yhat1 = result.params[0]+result.params[1]* 2.5
yhat1
# Out:
# 49417.10600230638

# %% [markdown]
# # **Visualization**

# %%
plt.scatter(x1,y,color = 'green')
plt.plot(x1,yhat)
plt.show()
